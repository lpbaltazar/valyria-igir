# %%
import pandas as pd
import numpy as np
import warnings
import re
import os

warnings.filterwarnings('ignore')

# %%
unprocessed_dir = os.path.abspath('../../unprocessed')
processed_dir = os.path.abspath('../../processed')
file = os.path.join(unprocessed_dir,'results.csv')
results = pd.read_csv(file, encoding = 'utf-8', dtype = {'PRECINCT_CODE':str})
results.shape
# Out:
# (20552238, 10)

# %%
contest = pd.read_csv(os.path.join(processed_dir, 'static/contests.csv'), encoding = 'utf-8')
# contest.rename({0:'CONTEST_CODE', 1: 'CONTEST_NAME'}, axis = 1, inplace = True)
positions = ['SENATOR', 'GOVERNOR', 'VICE-GOVERNOR', 'MAYOR', 'VICE-MAYOR','PARTY LIST']

# %%
codes = []
for pos in positions:
    mask = contest['CONTEST_NAME'].str.contains(pos)
    codes_1 = contest.loc[mask]
    codes.append(codes_1)
codes = pd.concat(codes)

# %%
candidates = pd.read_csv(os.path.join(processed_dir, 'static/candidates.csv'), encoding = 'utf-8')
candidates = candidates.loc[candidates['CONTEST_CODE'].isin(codes['CONTEST_CODE'].values)]

# %%
precincts = pd.read_csv(os.path.join(processed_dir, 'static/precincts.csv'), encoding = 'utf-8', dtype = {'VCM_ID':str})
precincts.columns
# Out:
# Index(['VCM_ID', 'REG_NAME', 'PRV_NAME', 'MUN_NAME', 'BRGY_NAME', 'POLLPLACE',
#        'CLUSTERED_PREC', 'REGISTERED_VOTERS'],
#       dtype='object')

# %%
results = results.merge(precincts, left_on = 'PRECINCT_CODE', right_on = 'VCM_ID', how = 'left')

# %%
results.columns
# Out:
# Index(['PRECINCT_CODE', 'CONTEST_CODE', 'CANDIDATE_NAME', 'PARTY_CODE',
#        'VOTES_AMOUNT', 'TOTALIZATION_ORDER', 'NUMBER_VOTERS', 'UNDERVOTE',
#        'OVERVOTE', 'RECEPTION_DATE', 'VCM_ID', 'REG_NAME', 'PRV_NAME',
#        'MUN_NAME', 'BRGY_NAME', 'POLLPLACE', 'CLUSTERED_PREC',
#        'REGISTERED_VOTERS'],
#       dtype='object')

# %%
results = results.loc[results['REG_NAME'] != 'OAV']
regions = results['REG_NAME'].unique()
unique_candidates = results.CANDIDATE_NAME.unique()

# %%
results.set_index('CANDIDATE_NAME', inplace = True)

# %%
grouped = results.groupby(['REG_NAME', 'CANDIDATE_NAME'])
keys = grouped.groups.keys()
region_summary = pd.DataFrame(index = results.REG_NAME.unique().tolist(), columns = candidates.CANDIDATE_NAME.values)
for key in keys:
    a = grouped.get_group(key)
    region_summary.loc[key[0]][key[1]] = a.VOTES_AMOUNT.sum()
region_summary
# Out:
#             ALVAREZ, JCA (PDPLBN) ABUY, BENILDA FATIMA (PFP)  \
# REGION IV-B                   312                        NaN
# REGION III                    NaN                        NaN
# REGION IV-A                   NaN                        621
# REGION VIII                   NaN                        NaN
# CAR                           NaN                        NaN
# REGION XI                     NaN                        NaN
# REGION IX                     NaN                        NaN
# REGION XIII                   NaN                        NaN
# REGION I                      NaN                        NaN
# REGION XII                    NaN                        NaN
# BARMM                         NaN                        NaN
# REGION VII                    NaN                        NaN
# REGION V                      NaN                        NaN
# REGION X                      NaN                        NaN
# REGION VI                     NaN                        NaN
# REGION II                     NaN                        NaN
# NCR                           NaN                        NaN
#
#             YNARES, NINI (NPC) JECOY, VILLA (PDPLBN) ESCUDERO, CHIZ (NPC)  \
# REGION IV-B                NaN                   NaN                  NaN
# REGION III                 NaN                   NaN                  NaN
# REGION IV-A               1423                   NaN                  NaN
# REGION VIII                NaN                   NaN                  NaN
# CAR                        NaN                   NaN                  NaN
# REGION XI                  NaN                   NaN                  NaN
# REGION IX                  NaN                   NaN                  NaN
# REGION XIII                NaN                   NaN                  NaN
# REGION I                   NaN                   NaN                  NaN
# REGION XII                 NaN                   NaN                  NaN
# BARMM                      NaN                   NaN                  NaN
# REGION VII                 NaN                   211                  NaN
# REGION V                   NaN                   NaN                   49
# REGION X                   NaN                   NaN                  NaN
# REGION VI                  NaN                   NaN                  NaN
# REGION II                  NaN                   NaN                  NaN
# NCR                        NaN                   NaN                  NaN
#
#             GALINDES, PADS ROLLIN (IND) BALMEO, BP (IND)  \
# REGION IV-B                         NaN              NaN
# REGION III                          NaN              NaN
# REGION IV-A                         NaN              NaN
# REGION VIII                         NaN              NaN
# CAR                                 NaN              NaN
# REGION XI                           NaN              NaN
# REGION IX                           NaN              NaN
# REGION XIII                         NaN              NaN
# REGION I                            NaN              NaN
# REGION XII                          NaN              NaN
# BARMM                               NaN              NaN
# REGION VII                          NaN              NaN
# REGION V                             44               39
# REGION X                            NaN              NaN
# REGION VI                           NaN              NaN
# REGION II                           NaN              NaN
# NCR                                 NaN              NaN
#
#             BUENAFLOR, BISHOP (PDDS) BANAAG, PERIOLO (PFP)  \
# REGION IV-B                      NaN                   NaN
# REGION III                       NaN                   NaN
# REGION IV-A                      NaN                   NaN
# REGION VIII                      NaN                   NaN
# CAR                              NaN                   NaN
# REGION XI                        NaN                   NaN
# REGION IX                        NaN                   NaN
# REGION XIII                      NaN                   NaN
# REGION I                         NaN                   NaN
# REGION XII                       NaN                   NaN
# BARMM                            NaN                   NaN
# REGION VII                       NaN                   NaN
# REGION V                         651                   NaN
# REGION X                         NaN                    84
# REGION VI                        NaN                   NaN
# REGION II                        NaN                   NaN
# NCR                              NaN                   NaN
#
#             SUPLIG, MARLON (LAKAS)     ...     92 AKO BISAYA 31 JUAN MOVEMENT  \
# REGION IV-B                    NaN     ...                50               83
# REGION III                     NaN     ...               193              213
# REGION IV-A                    NaN     ...               226              322
# REGION VIII                    NaN     ...               123              126
# CAR                            NaN     ...                49               42
# REGION XI                      NaN     ...                78               97
# REGION IX                      NaN     ...                72               87
# REGION XIII                    NaN     ...                43               96
# REGION I                       NaN     ...               120              120
# REGION XII                     NaN     ...                60               94
# BARMM                          NaN     ...                75               90
# REGION VII                     NaN     ...               138              155
# REGION V                       969     ...               113              141
# REGION X                       NaN     ...                96               96
# REGION VI                      NaN     ...               160              203
# REGION II                      NaN     ...                66               81
# NCR                            NaN     ...               129              157
#
#             8 1-UTAK 73 ALIF 127 AWAKE 139 ANUPA 103 APPEND 86 ALAY BUHAY  \
# REGION IV-B       77      57        50        52         57            48
# REGION III       210     225       174       169        189           213
# REGION IV-A      290     229       204       216        211           234
# REGION VIII      126     126       108       113        115           122
# CAR               42      45        36        42         42            47
# REGION XI        104      91        81        72         70            83
# REGION IX        102      51        66        69         72            60
# REGION XIII       99      43        29        36         41            39
# REGION I         116     114       108       105        113           117
# REGION XII        81      71        63        63         66            63
# BARMM            110      74        48        57         66            69
# REGION VII       141     134       135       128        152           146
# REGION V         179     121       105        96        110           118
# REGION X          96      91        84        87         96            90
# REGION VI        178     166       131       141        136           175
# REGION II         85      65        74        69         69            60
# NCR              164     136       135       135        124           141
#
#             27 AMEPA OFW 108 ABAKADA
# REGION IV-B           81          48
# REGION III           213         182
# REGION IV-A          317         201
# REGION VIII          125         122
# CAR                   42          33
# REGION XI            100          77
# REGION IX             93          69
# REGION XIII           99          42
# REGION I             114         108
# REGION XII            93          72
# BARMM                102          65
# REGION VII           170         144
# REGION V             154         110
# REGION X              99          86
# REGION VI            197         147
# REGION II             76          69
# NCR                  149         134
#
# [17 rows x 8297 columns]

# %%
grouped = results.groupby(['MUN_NAME', 'CANDIDATE_NAME'])
keys = grouped.groups.keys()
mun_summary = pd.DataFrame(index = results.MUN_NAME.unique().tolist(), columns = candidates.CANDIDATE_NAME.values)
for key in keys:
    a = grouped.get_group(key)
    mun_summary.loc[key[0]][key[1]] = a.VOTES_AMOUNT.sum()
mun_summary
# Out:
#                      ALVAREZ, JCA (PDPLBN) ABUY, BENILDA FATIMA (PFP)  \
# EL NIDO (BACUIT)                        18                        NaN
# LINAPACAN                                5                        NaN
# MAGSAYSAY                                9                        NaN
# NARRA                                   27                        NaN
# PUERTO PRINCESA CITY                   NaN                        NaN
# QUEZON                                  21                         10
# ROXAS                                   24                        NaN
# SAN VICENTE                             12                        NaN
# TAYTAY                                  27                        NaN
# KALAYAAN                                 0                        NaN
# CULION                                   9                        NaN
# RIZAL (MARCOS)                          15                        NaN
# SOFRONIO ESPAÑOLA                       13                        NaN
# ANGELES CITY                           NaN                        NaN
# APALIT                                 NaN                        NaN
# ARAYAT                                 NaN                        NaN
# BACOLOR                                NaN                        NaN
# CANDABA                                NaN                        NaN
# FLORIDABLANCA                          NaN                        NaN
# GUAGUA                                 NaN                        NaN
# LUBAO                                  NaN                        NaN
# MABALACAT CITY                         NaN                        NaN
# MACABEBE                               NaN                        NaN
# MAGALANG                               NaN                        NaN
# MASANTOL                               NaN                        NaN
# MEXICO                                 NaN                        NaN
# MINALIN                                NaN                        NaN
# PORAC                                  NaN                        NaN
# SAN FERNANDO CITY                      NaN                        NaN
# BINANGONAN                             NaN                        NaN
# ...                                    ...                        ...
# BAKUN                                  NaN                        NaN
# BOKOD                                  NaN                        NaN
# BUGUIAS                                NaN                        NaN
# ITOGON                                 NaN                        NaN
# KABAYAN                                NaN                        NaN
# KAPANGAN                               NaN                        NaN
# KIBUNGAN                               NaN                        NaN
# LA TRINIDAD                            NaN                        NaN
# MANKAYAN                               NaN                        NaN
# SAN JUAN CITY                          NaN                        NaN
# CALOOCAN CITY                          NaN                        NaN
# MALABON CITY                           NaN                        NaN
# NAVOTAS CITY                           NaN                        NaN
# TONDO                                  NaN                        NaN
# BINONDO                                NaN                        NaN
# QUIAPO                                 NaN                        NaN
# ERMITA                                 NaN                        NaN
# INTRAMUROS                             NaN                        NaN
# MALATE                                 NaN                        NaN
# PACO                                   NaN                        NaN
# PANDACAN                               NaN                        NaN
# PORT AREA                              NaN                        NaN
# BOAC                                   NaN                        NaN
# GASAN                                  NaN                        NaN
# MOGPOG                                 NaN                        NaN
# TORRIJOS                               NaN                        NaN
# AROROY                                 NaN                        NaN
# BALENO                                 NaN                        NaN
# BALUD                                  NaN                        NaN
# CATAINGAN                              NaN                        NaN
#
#                      YNARES, NINI (NPC) JECOY, VILLA (PDPLBN)  \
# EL NIDO (BACUIT)                    NaN                   NaN
# LINAPACAN                           NaN                   NaN
# MAGSAYSAY                           NaN                   NaN
# NARRA                               NaN                   NaN
# PUERTO PRINCESA CITY                NaN                   NaN
# QUEZON                              NaN                   NaN
# ROXAS                               NaN                   NaN
# SAN VICENTE                         NaN                   NaN
# TAYTAY                              133                   NaN
# KALAYAAN                            NaN                   NaN
# CULION                              NaN                   NaN
# RIZAL (MARCOS)                      NaN                   NaN
# SOFRONIO ESPAÑOLA                   NaN                   NaN
# ANGELES CITY                        NaN                   NaN
# APALIT                              NaN                   NaN
# ARAYAT                              NaN                   NaN
# BACOLOR                             NaN                   NaN
# CANDABA                             NaN                   NaN
# FLORIDABLANCA                       NaN                   NaN
# GUAGUA                              NaN                   NaN
# LUBAO                               NaN                   NaN
# MABALACAT CITY                      NaN                   NaN
# MACABEBE                            NaN                   NaN
# MAGALANG                            NaN                   NaN
# MASANTOL                            NaN                   NaN
# MEXICO                              NaN                   NaN
# MINALIN                             NaN                   NaN
# PORAC                               NaN                   NaN
# SAN FERNANDO CITY                   NaN                   NaN
# BINANGONAN                          124                   NaN
# ...                                 ...                   ...
# BAKUN                               NaN                   NaN
# BOKOD                               NaN                   NaN
# BUGUIAS                             NaN                   NaN
# ITOGON                              NaN                   NaN
# KABAYAN                             NaN                   NaN
# KAPANGAN                            NaN                   NaN
# KIBUNGAN                            NaN                   NaN
# LA TRINIDAD                         NaN                   NaN
# MANKAYAN                            NaN                   NaN
# SAN JUAN CITY                       NaN                   NaN
# CALOOCAN CITY                       NaN                   NaN
# MALABON CITY                        NaN                   NaN
# NAVOTAS CITY                        NaN                   NaN
# TONDO                               NaN                   NaN
# BINONDO                             NaN                   NaN
# QUIAPO                              NaN                   NaN
# ERMITA                              NaN                   NaN
# INTRAMUROS                          NaN                   NaN
# MALATE                              NaN                   NaN
# PACO                                NaN                   NaN
# PANDACAN                            NaN                   NaN
# PORT AREA                           NaN                   NaN
# BOAC                                NaN                   NaN
# GASAN                               NaN                   NaN
# MOGPOG                              NaN                   NaN
# TORRIJOS                            NaN                   NaN
# AROROY                              NaN                   NaN
# BALENO                              NaN                   NaN
# BALUD                               NaN                   NaN
# CATAINGAN                           NaN                   NaN
#
#                      ESCUDERO, CHIZ (NPC) GALINDES, PADS ROLLIN (IND)  \
# EL NIDO (BACUIT)                      NaN                         NaN
# LINAPACAN                             NaN                         NaN
# MAGSAYSAY                             NaN                         NaN
# NARRA                                 NaN                         NaN
# PUERTO PRINCESA CITY                  NaN                         NaN
# QUEZON                                NaN                         NaN
# ROXAS                                 NaN                         NaN
# SAN VICENTE                           NaN                         NaN
# TAYTAY                                NaN                         NaN
# KALAYAAN                              NaN                         NaN
# CULION                                NaN                         NaN
# RIZAL (MARCOS)                        NaN                         NaN
# SOFRONIO ESPAÑOLA                     NaN                         NaN
# ANGELES CITY                          NaN                         NaN
# APALIT                                NaN                         NaN
# ARAYAT                                NaN                         NaN
# BACOLOR                               NaN                         NaN
# CANDABA                               NaN                         NaN
# FLORIDABLANCA                         NaN                         NaN
# GUAGUA                                NaN                         NaN
# LUBAO                                 NaN                         NaN
# MABALACAT CITY                        NaN                         NaN
# MACABEBE                              NaN                         NaN
# MAGALANG                              NaN                         NaN
# MASANTOL                              NaN                         NaN
# MEXICO                                NaN                         NaN
# MINALIN                               NaN                         NaN
# PORAC                                 NaN                         NaN
# SAN FERNANDO CITY                     NaN                         NaN
# BINANGONAN                            NaN                         NaN
# ...                                   ...                         ...
# BAKUN                                 NaN                         NaN
# BOKOD                                 NaN                         NaN
# BUGUIAS                               NaN                         NaN
# ITOGON                                NaN                         NaN
# KABAYAN                               NaN                         NaN
# KAPANGAN                              NaN                         NaN
# KIBUNGAN                              NaN                         NaN
# LA TRINIDAD                           NaN                         NaN
# MANKAYAN                              NaN                         NaN
# SAN JUAN CITY                         NaN                         NaN
# CALOOCAN CITY                         NaN                         NaN
# MALABON CITY                          NaN                         NaN
# NAVOTAS CITY                          NaN                         NaN
# TONDO                                 NaN                         NaN
# BINONDO                               NaN                         NaN
# QUIAPO                                NaN                         NaN
# ERMITA                                NaN                         NaN
# INTRAMUROS                            NaN                         NaN
# MALATE                                NaN                         NaN
# PACO                                  NaN                         NaN
# PANDACAN                              NaN                         NaN
# PORT AREA                             NaN                         NaN
# BOAC                                  NaN                         NaN
# GASAN                                 NaN                         NaN
# MOGPOG                                NaN                         NaN
# TORRIJOS                              NaN                         NaN
# AROROY                                NaN                         NaN
# BALENO                                NaN                         NaN
# BALUD                                 NaN                         NaN
# CATAINGAN                             NaN                         NaN
#
#                      BALMEO, BP (IND) BUENAFLOR, BISHOP (PDDS)  \
# EL NIDO (BACUIT)                  NaN                      NaN
# LINAPACAN                         NaN                      NaN
# MAGSAYSAY                         NaN                      NaN
# NARRA                             NaN                      NaN
# PUERTO PRINCESA CITY              NaN                      NaN
# QUEZON                            NaN                      NaN
# ROXAS                             NaN                      NaN
# SAN VICENTE                         3                      NaN
# TAYTAY                            NaN                      NaN
# KALAYAAN                          NaN                      NaN
# CULION                            NaN                      NaN
# RIZAL (MARCOS)                    NaN                      NaN
# SOFRONIO ESPAÑOLA                 NaN                      NaN
# ANGELES CITY                      NaN                      NaN
# APALIT                            NaN                      NaN
# ARAYAT                            NaN                      NaN
# BACOLOR                           NaN                      NaN
# CANDABA                           NaN                      NaN
# FLORIDABLANCA                     NaN                      NaN
# GUAGUA                            NaN                      NaN
# LUBAO                             NaN                      NaN
# MABALACAT CITY                    NaN                      NaN
# MACABEBE                          NaN                      NaN
# MAGALANG                          NaN                      NaN
# MASANTOL                          NaN                      NaN
# MEXICO                            NaN                      NaN
# MINALIN                           NaN                      NaN
# PORAC                             NaN                      NaN
# SAN FERNANDO CITY                 NaN                      NaN
# BINANGONAN                        NaN                      NaN
# ...                               ...                      ...
# BAKUN                             NaN                      NaN
# BOKOD                             NaN                      NaN
# BUGUIAS                           NaN                      NaN
# ITOGON                            NaN                      NaN
# KABAYAN                           NaN                      NaN
# KAPANGAN                          NaN                      NaN
# KIBUNGAN                          NaN                      NaN
# LA TRINIDAD                       NaN                      NaN
# MANKAYAN                          NaN                      NaN
# SAN JUAN CITY                     NaN                      NaN
# CALOOCAN CITY                     NaN                      NaN
# MALABON CITY                      NaN                      NaN
# NAVOTAS CITY                      NaN                      NaN
# TONDO                             NaN                      NaN
# BINONDO                           NaN                      NaN
# QUIAPO                            NaN                      NaN
# ERMITA                            NaN                      NaN
# INTRAMUROS                        NaN                      NaN
# MALATE                            NaN                      NaN
# PACO                              NaN                      NaN
# PANDACAN                          NaN                      NaN
# PORT AREA                         NaN                      NaN
# BOAC                              NaN                      NaN
# GASAN                             NaN                      NaN
# MOGPOG                            NaN                      NaN
# TORRIJOS                          NaN                      NaN
# AROROY                            NaN                      NaN
# BALENO                            NaN                      NaN
# BALUD                             NaN                      NaN
# CATAINGAN                         NaN                      NaN
#
#                      BANAAG, PERIOLO (PFP) SUPLIG, MARLON (LAKAS)     ...      \
# EL NIDO (BACUIT)                       NaN                    NaN     ...
# LINAPACAN                              NaN                    NaN     ...
# MAGSAYSAY                              NaN                    NaN     ...
# NARRA                                  NaN                    NaN     ...
# PUERTO PRINCESA CITY                   NaN                    NaN     ...
# QUEZON                                 NaN                    NaN     ...
# ROXAS                                  NaN                    NaN     ...
# SAN VICENTE                            NaN                    NaN     ...
# TAYTAY                                 NaN                    NaN     ...
# KALAYAAN                               NaN                    NaN     ...
# CULION                                 NaN                    NaN     ...
# RIZAL (MARCOS)                         NaN                    NaN     ...
# SOFRONIO ESPAÑOLA                      NaN                    NaN     ...
# ANGELES CITY                           NaN                    NaN     ...
# APALIT                                 NaN                    NaN     ...
# ARAYAT                                 NaN                    NaN     ...
# BACOLOR                                NaN                    NaN     ...
# CANDABA                                NaN                    NaN     ...
# FLORIDABLANCA                          NaN                    NaN     ...
# GUAGUA                                 NaN                    NaN     ...
# LUBAO                                  NaN                    NaN     ...
# MABALACAT CITY                         NaN                    NaN     ...
# MACABEBE                               NaN                    NaN     ...
# MAGALANG                               NaN                    NaN     ...
# MASANTOL                               NaN                    NaN     ...
# MEXICO                                 NaN                    NaN     ...
# MINALIN                                NaN                    NaN     ...
# PORAC                                  NaN                    NaN     ...
# SAN FERNANDO CITY                      NaN                    NaN     ...
# BINANGONAN                             NaN                    NaN     ...
# ...                                    ...                    ...     ...
# BAKUN                                  NaN                    NaN     ...
# BOKOD                                  NaN                    NaN     ...
# BUGUIAS                                NaN                    NaN     ...
# ITOGON                                 NaN                    NaN     ...
# KABAYAN                                NaN                    NaN     ...
# KAPANGAN                               NaN                    NaN     ...
# KIBUNGAN                               NaN                    NaN     ...
# LA TRINIDAD                            NaN                    NaN     ...
# MANKAYAN                               NaN                    NaN     ...
# SAN JUAN CITY                          NaN                    NaN     ...
# CALOOCAN CITY                          NaN                    NaN     ...
# MALABON CITY                           NaN                    NaN     ...
# NAVOTAS CITY                           NaN                    NaN     ...
# TONDO                                  NaN                    NaN     ...
# BINONDO                                NaN                    NaN     ...
# QUIAPO                                 NaN                    NaN     ...
# ERMITA                                 NaN                    NaN     ...
# INTRAMUROS                             NaN                    NaN     ...
# MALATE                                 NaN                    NaN     ...
# PACO                                   NaN                    NaN     ...
# PANDACAN                               NaN                    NaN     ...
# PORT AREA                              NaN                    NaN     ...
# BOAC                                   NaN                    NaN     ...
# GASAN                                  NaN                    NaN     ...
# MOGPOG                                 NaN                    NaN     ...
# TORRIJOS                               NaN                    NaN     ...
# AROROY                                 NaN                    NaN     ...
# BALENO                                 NaN                    NaN     ...
# BALUD                                  NaN                    NaN     ...
# CATAINGAN                              NaN                    NaN     ...
#
#                      92 AKO BISAYA 31 JUAN MOVEMENT 8 1-UTAK 73 ALIF  \
# EL NIDO (BACUIT)                 0                3        2       0
# LINAPACAN                        3                0        0       0
# MAGSAYSAY                        3                1        6       3
# NARRA                            0                3        3       0
# PUERTO PRINCESA CITY             3                3        3       3
# QUEZON                           7                9        0       6
# ROXAS                            3                5        6       6
# SAN VICENTE                      3                3        3       0
# TAYTAY                           3                6        6       6
# KALAYAAN                         0                0        0       0
# CULION                           0                3        0       0
# RIZAL (MARCOS)                   0                3        3       0
# SOFRONIO ESPAÑOLA                0                0        0       0
# ANGELES CITY                     6                3        3       3
# APALIT                           3                0        0       3
# ARAYAT                           3                3        3       3
# BACOLOR                          0                3        3       3
# CANDABA                          3                0        0       3
# FLORIDABLANCA                    3                0        0       3
# GUAGUA                           3                3        3       3
# LUBAO                            3                0        0       3
# MABALACAT CITY                   3                3        3       3
# MACABEBE                         0                3        3       3
# MAGALANG                         3                3        3       3
# MASANTOL                         3                0        0       0
# MEXICO                           3                0        0       3
# MINALIN                          0                0        0       0
# PORAC                            0                3        3       3
# SAN FERNANDO CITY                3                6        6       6
# BINANGONAN                       3                3        3       3
# ...                            ...              ...      ...     ...
# BAKUN                            0                0        0       0
# BOKOD                            0                0        3       0
# BUGUIAS                          3                3        0       3
# ITOGON                           3                3        0       3
# KABAYAN                          0                0        0       0
# KAPANGAN                         0                0        6       0
# KIBUNGAN                         0                3        0       0
# LA TRINIDAD                      3                0        0       3
# MANKAYAN                         0                0        0       0
# SAN JUAN CITY                    0                6        6       0
# CALOOCAN CITY                    6                6        6       6
# MALABON CITY                     6                6        6       6
# NAVOTAS CITY                     3                6        6       3
# TONDO                            9               10       11       9
# BINONDO                          0                0        3       0
# QUIAPO                           3                0        0       3
# ERMITA                           0                0        3       0
# INTRAMUROS                       0                3        0       0
# MALATE                           3                0        0       3
# PACO                             0                6        6       0
# PANDACAN                         0                0        0       0
# PORT AREA                        0                0        0       0
# BOAC                             0                3        3       3
# GASAN                            0                0        0       0
# MOGPOG                           0                0        0       0
# TORRIJOS                         3                0        0       0
# AROROY                           3                3        3       3
# BALENO                           0                3        3       0
# BALUD                            0                0        0       3
# CATAINGAN                        0                3        0       3
#
#                      127 AWAKE 139 ANUPA 103 APPEND 86 ALAY BUHAY  \
# EL NIDO (BACUIT)             0         0          0             0
# LINAPACAN                    0         0          3             0
# MAGSAYSAY                    2         0          3             0
# NARRA                        0         0          0             0
# PUERTO PRINCESA CITY         6         6          3             3
# QUEZON                       3         3          3             9
# ROXAS                        0         0          3             3
# SAN VICENTE                  0         3          0             0
# TAYTAY                       3         8          3             3
# KALAYAAN                     0         0          0             0
# CULION                       0         0          0             0
# RIZAL (MARCOS)               0         0          0             0
# SOFRONIO ESPAÑOLA            0         0          0             0
# ANGELES CITY                 3         6          6             6
# APALIT                       3         3          3             3
# ARAYAT                       3         3          3             3
# BACOLOR                      0         0          0             3
# CANDABA                      3         3          3             3
# FLORIDABLANCA                3         3          3             6
# GUAGUA                       0         0          3             3
# LUBAO                        3         3          3             3
# MABALACAT CITY               3         3          0             3
# MACABEBE                     0         0          0             0
# MAGALANG                     0         0          3             3
# MASANTOL                     3         3          3             3
# MEXICO                       3         3          3             3
# MINALIN                      0         3          0             0
# PORAC                        0         0          3             0
# SAN FERNANDO CITY            3         3          3             3
# BINANGONAN                   3         6          3             3
# ...                        ...       ...        ...           ...
# BAKUN                        0         3          0             0
# BOKOD                        0         0          0             0
# BUGUIAS                      0         0          0             3
# ITOGON                       0         0          0             3
# KABAYAN                      3         0          3             0
# KAPANGAN                     0         0          0             0
# KIBUNGAN                     0         0          0             0
# LA TRINIDAD                  0         0          3             3
# MANKAYAN                     0         0          0             0
# SAN JUAN CITY                0         0          0             0
# CALOOCAN CITY                6         6          6             6
# MALABON CITY                 6         6          6             6
# NAVOTAS CITY                 0         3          6             6
# TONDO                       12        12         12             9
# BINONDO                      0         0          0             0
# QUIAPO                       0         0          0             3
# ERMITA                       0         0          0             0
# INTRAMUROS                   0         0          0             0
# MALATE                       3         0          3             3
# PACO                         0         0          0             0
# PANDACAN                     0         0          0             0
# PORT AREA                    0         3          0             0
# BOAC                         0         0          0             3
# GASAN                        3         3          0             0
# MOGPOG                       0         0          0             0
# TORRIJOS                     3         0          3             0
# AROROY                       0         0          0             3
# BALENO                       0         0          0             0
# BALUD                        0         0          0             3
# CATAINGAN                    0         0          0             3
#
#                      27 AMEPA OFW 108 ABAKADA
# EL NIDO (BACUIT)                3           0
# LINAPACAN                       0           0
# MAGSAYSAY                       5           0
# NARRA                           3           0
# PUERTO PRINCESA CITY            3           6
# QUEZON                          6           3
# ROXAS                           6           0
# SAN VICENTE                     3           0
# TAYTAY                          6           0
# KALAYAAN                        3           0
# CULION                          3           0
# RIZAL (MARCOS)                  3           0
# SOFRONIO ESPAÑOLA               0           0
# ANGELES CITY                    3           6
# APALIT                          0           3
# ARAYAT                          3           3
# BACOLOR                         3           0
# CANDABA                         0           3
# FLORIDABLANCA                   0           3
# GUAGUA                          3           0
# LUBAO                           0           3
# MABALACAT CITY                  3           3
# MACABEBE                        3           0
# MAGALANG                        3           3
# MASANTOL                        0           3
# MEXICO                          0           3
# MINALIN                         0           0
# PORAC                           3           3
# SAN FERNANDO CITY               6           3
# BINANGONAN                      3           3
# ...                           ...         ...
# BAKUN                           0           0
# BOKOD                           3           0
# BUGUIAS                         0           0
# ITOGON                          0           0
# KABAYAN                         0           3
# KAPANGAN                        3           0
# KIBUNGAN                        3           0
# LA TRINIDAD                     0           3
# MANKAYAN                        0           0
# SAN JUAN CITY                   6           0
# CALOOCAN CITY                   6           6
# MALABON CITY                    6           6
# NAVOTAS CITY                    6           6
# TONDO                          12          12
# BINONDO                         0           0
# QUIAPO                          0           0
# ERMITA                          0           0
# INTRAMUROS                      3           0
# MALATE                          0           3
# PACO                            3           0
# PANDACAN                        0           0
# PORT AREA                       0           0
# BOAC                            3           0
# GASAN                           0           0
# MOGPOG                          0           0
# TORRIJOS                        0           3
# AROROY                          3           0
# BALENO                          3           0
# BALUD                           0           0
# CATAINGAN                       3           0
#
# [1438 rows x 8297 columns]

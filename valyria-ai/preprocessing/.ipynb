# %%
import pandas as pd
import numpy as np
import warnings
import re
import os

warnings.filterwarnings('ignore')

# %%
file = os.path.abspath('../../unprocessed/results_0.csv')
results = pd.read_csv(file, encoding = 'utf-8')
results
# Out:
#         Unnamed: 0  PRECINCT_CODE  CONTEST_CODE  \
# 0                0         441744       1050334
# 1                1         441744       1050334
# 2                2         441744       1050334
# 3                3         441744       1050334
# 4                4         441744       1050334
# 5                5         441744       1050334
# 6                6         441744       1050334
# 7                7         441744       1050334
# 8                8         441744       1050334
# 9                9         441744       1050334
# 10              10         441744       1050335
# 11              11         441744       1050335
# 12              12         441744       1050335
# 13              13         441744       1050335
# 14              14         441744       1050335
# 15              15         441744       1050335
# 16              16         441744       1050335
# 17              17         441744       1050335
# ...
